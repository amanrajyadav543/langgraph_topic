# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from dotenv import load_dotenv
import os
from langchain_groq import ChatGroq

# %%
load_dotenv()
model = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
class BlogState(TypedDict):
    title:str
    outline:str
    content:str

# %%
def create_outline(state:BlogState)->BlogState:
    title = state['title']
    prompt = f'Generate a detailed blog outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    return state

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here\'s a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* India\'s potential to become a leader in AI adoption and development\n* Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and a growing talent pool, transforming various industries and sectors.\n\n**II. Government Initiatives and Policies**\n\n* Overview of the Indian government\'s AI strategy and initiatives, such as:\n\t+ National AI Mission (NAIM)\n\t+ AI Task Force\n\t+ Digital India initiative\n* Discussion on how these initiatives aim to promote AI adoption, research, and development in India\n* Examples of government-funded AI projects and programs, such as:\n\t+ AI-powered healthcare systems\n\t+ Intelligent transportation systems\n\t+ AI-based education platforms\n\n**III. AI Adoption in Key Industries**\n\n* Overview of AI adoption in various industries in India, including:\n\t+ Healthcare: AI-powered diagnosis, patient care, and medical research\n\t+ Finance: AI-powered banking, insurance, and investment platforms\n\t+ Manufacturing: AI-powered supply chain management, quality control, and predictive maintenance\n\t+ Education: AI-powered learning platforms, adaptive assessments, and personalized learning\n* Examples of Indian companies and startups leveraging AI in these industries, such as:\n\t+ Healthcare: Apollo Hospitals, Fortis Healthcare\n\t+ Finance: HDFC Bank, ICICI Bank\n\t+ Manufacturing: Tata Motors, Mahindra & Mahindra\n\t+ Education: BYJU\'S, Vedantu\n\n**IV. AI Research and Development in India**\n\n* Overview of AI research and development in India, including:\n\t+ Academic institutions: IITs, IIITs, and other top universities\n\t+ Research institutions: Indian Institute of Science (IISc), Tata Institute of Fundamental Research (TIFR)\n\t+ Private sector: Microsoft, Google, IBM, and other multinational companies\n* Discussion on the focus areas of AI research in India, such as:\n\t+ Natural Language Processing (NLP)\n\t+ Computer Vision\n\t+ Machine Learning (ML)\n\t+ Robotics\n\n**V. AI Talent Pool and Skills Development**\n\n* Overview of the AI talent pool in India, including:\n\t+ Availability of skilled professionals\n\t+ Shortage of skilled professionals in certain areas\n* Discussion on initiatives to develop AI skills in India, such as:\n\t+ AI and ML courses offered by universities and institutes\n\t+ Online courses and certification programs\n\t+ Industry-academia partnerships for skills development\n* Examples of Indian companies and startups offering AI training and certification programs, such as:\n\t+ Great Learning\n\t+ Simplilearn\n\t+ UpGrad\n\n**VI. Challenges and Opportunities**\n\n* Discussion on the challenges facing AI adoption in India, such as:\n\t+ Data quality and availability\n\t+ Infrastructure and computational resources\n\t+ Regulatory frameworks and ethics\n* Overview of the opportunities for AI growth in India, including:\n\t+ Large and growing market\n\t+ Availability of talent and skills\n\t+ Government support and initiatives\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool\n* Future outlook for AI in India, including potential applications and growth areas\n* Final thoughts: India\'s potential to become a leader in AI adoption and development, and the need for continued investment, innovation, and collaboration to achieve this goal.\n\nThis outline provides a comprehensive framework for exploring the rise of AI in India, covering key aspects such as government initiatives, industry adoption, research and development, talent pool, and challenges and opportunities.', 'content': "**The Rise of AI in India: A New Era of Innovation and Growth**\n\nArtificial  ...

# %%
print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * India's potential to become a leader in AI adoption and development
# * Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and a growing talent pool, transforming various industries and sectors.
#
# **II. Government Initiatives and Policies**
#
# * Overview of the Indian government's AI strategy and initiatives, such as:
# 	+ National AI Mission (NAIM)
# 	+ AI Task Force
# 	+ Digital India initiative
# * Discussion on how these initiatives aim to promote AI adoption, research, and development in India
# * Examples of government-funded AI projects and programs, such as:
# 	+ AI-powered healthcare systems
# 	+ Intelligent transportation systems
# 	+ AI-based education platforms
#
# **III. AI Adoption in Key Industries**
#
# * Overview of AI adoption in various industries in India, including:
# 	+ Healthcare: AI-powered diagnosis, patient care, and medical research
# 	+ Finance: AI-powered banking, insurance, and investment platforms
# 	+ Manufacturing: AI-powered supply chain management, quality control, and predictive maintenance
# 	+ Education: AI-powered learning platforms, adaptive assessments, and personalized learning
# * Examples of Indian companies and startups leveraging AI in these industries, such as:
# 	+ Healthcare: Apollo Hospitals, Fortis Healthcare
# 	+ Finance: HDFC Bank, ICICI Bank
# 	+ Manufacturing: Tata Motors, Mahindra & Mahindra
# 	+ Education: BYJU'S, Vedantu
#
# **IV. AI Research and Development in India**
#
# * Overview of AI research and development in India, including:
# 	+ Academic institutions: IITs, IIITs, and other top universities
# 	+ Research institutions: Indian Institute of Science (IISc), Tata Institute of Fundamental Research (TIFR)
# 	+ Private sector: Microsoft, Google, IBM, and other multinational companies
# * Discussion on the focus areas of AI research in India, such as:
# 	+ Natural Language Processing (NLP)
# 	+ Computer Vision
# 	+ Machine Learning (ML)
# 	+ Robotics
#
# **V. AI Talent Pool and Skills Development**
#
# * Overview of the AI talent pool in India, including:
# 	+ Availability of skilled professionals
# 	+ Shortage of skilled professionals in certain areas
# * Discussion on initiatives to develop AI skills in India, such as:
# 	+ AI and ML courses offered by universities and institutes
# 	+ Online courses and certification programs
# 	+ Industry-academia partnerships for skills development
# * Examples of Indian companies and startups offering AI training and certification programs, such as:
# 	+ Great Learning
# 	+ Simplilearn
# 	+ UpGrad
#
# **VI. Challenges and Opportunities**
#
# * Discussion on the challenges facing AI adoption in India, such as:
# 	+ Data quality and availability
# 	+ Infrastructure and computational resources
# 	+ Regulatory frameworks and ethics
# * Overview of the opportunities for AI growth in India, including:
# 	+ Large and growing market
# 	+ Availability of talent and skills
# 	+ Government support and initiatives
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool
# * Future outlook for AI in India, including potential applications and growth areas
# * Final thoughts: India's potential to become a leader in AI adoption and development, and the need for continued investment, innovation, and collaboration to achieve this goal.
#
# This outline provides a comprehensive framework for exploring the rise of AI in India, covering key aspects such as government initiatives, industry adoption, research and development, talent pool, and challenges and opportunities.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# Artificial Intelligence (AI) has been making waves globally, transforming industries and revolutionizing the way we live and work. India, with its vast talent pool, growing economy, and government support, is poised to become a leader in AI adoption and development. In this blog, we will explore the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool, and how it is transforming various industries and sectors.
#
# **Government Initiatives and Policies**
#
# The Indian government has been proactive in promoting AI adoption and development in the country. The National AI Mission (NAIM) is a key initiative aimed at making India a global leader in AI. The AI Task Force, set up by the government, has recommended a number of measures to promote AI adoption, including the creation of a National AI Institute and the development of a national AI strategy. The Digital India initiative, launched by the government in 2015, has also played a crucial role in promoting the use of technology and AI in various sectors.
#
# The government has also launched a number of AI-powered projects and programs, such as AI-powered healthcare systems, intelligent transportation systems, and AI-based education platforms. For example, the government has launched an AI-powered platform to detect and diagnose diseases such as cancer and tuberculosis. The platform uses machine learning algorithms to analyze medical images and provide accurate diagnoses. Similarly, the government has launched an intelligent transportation system to manage traffic flow and reduce congestion in cities.
#
# **AI Adoption in Key Industries**
#
# AI is being adopted in various industries in India, including healthcare, finance, manufacturing, and education. In healthcare, AI is being used to improve patient care and outcomes. For example, Apollo Hospitals has launched an AI-powered platform to detect and diagnose diseases such as cancer and tuberculosis. Fortis Healthcare has also launched an AI-powered platform to provide personalized medicine and treatment plans to patients.
#
# In finance, AI is being used to improve customer service and reduce fraud. For example, HDFC Bank has launched an AI-powered chatbot to provide customer support and answer queries. ICICI Bank has also launched an AI-powered platform to detect and prevent fraud. In manufacturing, AI is being used to improve supply chain management and quality control. For example, Tata Motors has launched an AI-powered platform to manage its supply chain and predict demand. Mahindra & Mahindra has also launched an AI-powered platform to improve quality control and reduce defects.
#
# In education, AI is being used to improve learning outcomes and provide personalized learning experiences. For example, BYJU'S has launched an AI-powered learning platform to provide personalized learning experiences to students. Vedantu has also launched an AI-powered platform to provide adaptive assessments and personalized learning plans to students.
#
# **AI Research and Development in India**
#
# India has a strong research and development ecosystem in AI, with a number of academic institutions, research institutions, and private sector companies working on AI research and development. The Indian Institute of Technology (IIT) and the Indian Institute of Information Technology (IIIT) are among the top institutions in the country for AI research and development. The Indian Institute of Science (IISc) and the Tata Institute of Fundamental Research (TIFR) are also among the top research institutions in the country.
#
# The private sector is also playing a crucial role in AI research and development in India. Companies such as Microsoft, Google, and IBM have set up research centers in India to work on AI research and development. The focus areas of AI research in India include natural language processing, computer vision, machine learning, and robotics. For example, researchers at IIT Delhi have developed an AI-powered system to translate Indian languages into English. Researchers at IISc have also developed an AI-powered system to detect and diagnose diseases such as cancer and tuberculosis.
#
# **AI Talent Pool and Skills Development**
#
# India has a large and growing talent pool in AI, with a number of skilled professionals working in the field. However, there is still a shortage of skilled professionals in certain areas, such as machine learning and natural language processing. To address this shortage, a number of initiatives have been launched to develop AI skills in India. For example, a number of universities and institutes are offering AI and ML courses to students. Online courses and certification programs are also being offered by companies such as Great Learning, Simplilearn, and UpGrad.
#
# Industry-academia partnerships are also being formed to develop AI skills in India. For example, IIT Delhi has partnered with Microsoft to launch an AI research center. IISc has also partnered with Google to launch an AI research center. These partnerships are helping to develop AI skills in India and provide opportunities for students and professionals to work on AI research and development projects.
#
# **Challenges and Opportunities**
#
# Despite the progress made in AI adoption and development in India, there are still a number of challenges that need to be addressed. One of the major challenges is the lack of data quality and availability. AI algorithms require large amounts of data to learn and improve, and the lack of data in India is a major constraint. Another challenge is the lack of infrastructure and computational resources. AI requires powerful computers and large amounts of storage, and the lack of infrastructure in India is a major constraint.
#
# However, there are also a number of opportunities for AI growth in India. The country has a large and growing market, with a number of industries and sectors that can benefit from AI adoption. The availability of talent and skills is also a major opportunity, with a number of skilled professionals working in the field. The government support and initiatives are also a major opportunity, with the government launching a number of initiatives to promote AI adoption and development.
#
# **Conclusion**
#
# In conclusion, the rise of AI in India is a significant trend that is transforming various industries and sectors. The government initiatives and policies, AI adoption in key industries, AI research and development, and AI talent pool and skills development are all contributing to the growth of AI in India. While there are challenges that need to be addressed, the opportunities for AI growth in India are significant. With continued investment, innovation, and collaboration, India has the potential to become a leader in AI adoption and development, and to reap the benefits of AI in terms of economic growth, job creation, and improved living standards.
#
# The future outlook for AI in India is promising, with a number of potential applications and growth areas. For example, AI can be used to improve healthcare outcomes, enhance customer service, and optimize supply chain management. AI can also be used to improve education, provide personalized learning experiences, and enhance student outcomes. With the right investments and initiatives, India can become a leader in AI adoption and development, and can reap the benefits of AI in terms of economic growth, job creation, and improved living standards.
#
# In the end, the rise of AI in India is a significant trend that has the potential to transform the country and improve the lives of its citizens. With the right investments, initiatives, and collaborations, India can become a leader in AI adoption and development, and can reap the benefits of AI in terms of economic growth, job creation, and improved living standards.
